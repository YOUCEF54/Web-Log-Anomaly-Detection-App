# %% [markdown]
# # 📌 04 – Model Evaluation & Visualization
#
# “This notebook evaluates the trained models through performance metrics and visualizations such as classification reports and confusion matrices.”

# %% [markdown]
# *– Imports*

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))



import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from features import build_features

# Load IsolationForest model
iso = joblib.load("../models/iso_model.joblib")

# %% [markdown]
# *— Charger dataset + features :*

# %%
df = pd.read_csv("../data/csic_database.csv")
df["label"] = df["label"].astype(int)

X, feature_cols = build_features(df)
y = df["label"]

# %% [markdown]
# *— Charger modèle RF :*

# %%
rf = joblib.load("../models/rf_model.joblib")
preds = rf.predict(X)

# %% [markdown]
# *— Report + matrice :*

# %%
print(classification_report(y, preds))

cm = confusion_matrix(y, preds)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("RandomForest — Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     88000
#            1       0.98      0.42      0.59     35042
#
#     accuracy                           0.83    123042
#    macro avg       0.90      0.71      0.74    123042
# weighted avg       0.86      0.83      0.81    123042

# %% [markdown]
# *– Feature Importance (VERY IMPORTANT FOR PRESENTATION)*

# %%
importances = rf.feature_importances_

plt.figure(figsize=(8,5))
sns.barplot(x=importances, y=feature_cols, orient="h")
plt.title("Feature Importance – RandomForest")
plt.show()

# %% [markdown]
# *– IsolationForest Anomaly Scores*

# %%
iso_scores = iso.decision_function(X)

plt.figure(figsize=(8,4))
plt.hist(iso_scores, bins=50, color="salmon")
plt.title("Isolation Forest – Anomaly Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# *– Visualize Anomalous Points*

# %%
df["iso_prediction"] = iso.predict(X)

anomalies = df[df["iso_prediction"] == -1]

anomalies.head()
# Out:
#     method                                                url  protocol  \
# 15     GET  http://localhost:8080/tienda1/publico/pagar.js...  HTTP/1.1
# 59     GET  http://localhost:8080/tienda1/publico/pagar.js...  HTTP/1.1
# 63     GET  http://localhost:8080/tienda1/publico/registro...  HTTP/1.1
# 103    GET  http://localhost:8080/tienda1/publico/pagar.js...  HTTP/1.1
# 147    GET  http://localhost:8080/tienda1/publico/pagar.js...  HTTP/1.1
#
#                host                                         user_agent  \
# 15   localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 59   localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 63   localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 103  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 147  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
#
#                                           cookie content_type  content_length  \
# 15   JSESSIONID=535529056CAF606E044AC8C76F6E6C40          NaN             NaN
# 59   JSESSIONID=2A0DAF6374B66B52F63973D50A5EF0B1          NaN             NaN
# 63   JSESSIONID=E577BCD896318833F8D03A610920698E          NaN             NaN
# 103  JSESSIONID=DFEF8EFFD2A0DBCA9D5B5D32AA9069FD          NaN             NaN
# 147  JSESSIONID=87A7AC2C0B5A6275061869EEE08205EA          NaN             NaN
#
#      body  label  iso_prediction
# 15    NaN      0              -1
# 59    NaN      0              -1
# 63    NaN      0              -1
# 103   NaN      0              -1
# 147   NaN      0              -1
