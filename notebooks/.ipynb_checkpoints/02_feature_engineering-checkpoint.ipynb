# %% [markdown]
# # 📌 02 – Feature Engineering for Web Log Anomaly Detection
#
# “This notebook applies feature engineering to transform raw HTTP requests into meaningful numerical security features used for machine learning models.”

# %% [markdown]
# *– Imports :*

# %%
import sys
import os

# Add the src folder to Python path
sys.path.append(os.path.abspath("../src"))

from features import build_features

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from features import build_features

# %% [markdown]
# *— Charger dataset :*

# %%
df = pd.read_csv("../data/csic_database.csv")
df.head()
# Out:
#   method                                                url  protocol  \
# 0    GET            http://localhost:8080/tienda1/index.jsp  HTTP/1.1
# 1    GET  http://localhost:8080/tienda1/publico/anadir.j...  HTTP/1.1
# 2   POST   http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3    NaN                                                NaN       NaN
# 4    GET  http://localhost:8080/tienda1/publico/autentic...  HTTP/1.1
#
#              host                                         user_agent  \
# 0  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 1  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 2  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 3             NaN                                                NaN
# 4  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
#
#                                         cookie  \
# 0  JSESSIONID=1F767F17239C9B670A39E9B10C3825F4
# 1  JSESSIONID=81761ACA043B0E6014CA42A4BCD06AB5
# 2  JSESSIONID=933185092E0B668B90676E0A2B0767AF
# 3                                          NaN
# 4  JSESSIONID=8FA18BA82C5336D03D3A8AFA3E68CBB0
#
#                         content_type  content_length  body  label
# 0                                NaN             NaN   NaN      0
# 1                                NaN             NaN   NaN      0
# 2  application/x-www-form-urlencoded            68.0   NaN      0
# 3                                NaN             NaN   NaN      0
# 4                                NaN             NaN   NaN      0

# %% [markdown]
# *— Générer les features :*

# %%
X, feature_cols = build_features(df)

X.head(), feature_cols
# Out:
# (   url_length  param_count  has_special_chars  has_sql  method_encoded  \
#  0          39            0                  0        0               0
#  1         117            4                  1        0               0
#  2          48            0                  0        0               1
#  3           0            0                  0        0               0
#  4         116            4                  1        0               0
#
#     payload_length  accept_length  useragent_length  cookie_length  \
#  0               0              0                71             43
#  1               0              0                71             43
#  2               0              0                71             43
#  3               0              0                 0              0
#  4               0              0                71             43
#
#     url_entropy  content_entropy  contains_digits  contains_equal  \
#  0     4.208479                0                1               0
#  1     4.759970                0                1               1
#  2     4.280188                0                1               0
#  3     0.000000                0                0               0
#  4     4.785122                0                1               1
#
#     contains_question  is_form
#  0                  0        0
#  1                  1        0
#  2                  0        1
#  3                  0        0
#  4                  1        0  ,
#  ['url_length',
#   'param_count',
#   'has_special_chars',
#   'has_sql',
#   'method_encoded',
#   'payload_length',
#   'accept_length',
#   'useragent_length',
#   'cookie_length',
#   'url_entropy',
#   'content_entropy',
#   'contains_digits',
#   'contains_equal',
#   'contains_question',
#   'is_form'])

# %% [markdown]
# *— Statistiques descriptives :*

# %%
X.describe()
# Out:
#           url_length    param_count  has_special_chars        has_sql  \
# count  123042.000000  123042.000000      123042.000000  123042.000000
# mean       60.846987       0.929455           0.112116       0.034257
# std        69.877066       2.827205           0.315511       0.181888
# min         0.000000       0.000000           0.000000       0.000000
# 25%        44.000000       0.000000           0.000000       0.000000
# 50%        48.000000       0.000000           0.000000       0.000000
# 75%        58.000000       0.000000           0.000000       0.000000
# max       886.000000      12.000000           1.000000       1.000000
#
#        method_encoded  payload_length  accept_length  useragent_length  \
# count   123042.000000        123042.0       123042.0     123042.000000
# mean         0.207896             0.0            0.0         56.010265
# std          0.405804             0.0            0.0         28.975608
# min          0.000000             0.0            0.0          0.000000
# 25%          0.000000             0.0            0.0         71.000000
# 50%          0.000000             0.0            0.0         71.000000
# 75%          0.000000             0.0            0.0         71.000000
# max          1.000000             0.0            0.0         71.000000
#
#        cookie_length    url_entropy  content_entropy  contains_digits  \
# count  123042.000000  123042.000000         123042.0    123042.000000
# mean       33.921710       3.478886              0.0         0.788877
# std        17.548608       1.815945              0.0         0.408107
# min         0.000000       0.000000              0.0         0.000000
# 25%        43.000000       4.161313              0.0         1.000000
# 50%        43.000000       4.280470              0.0         1.000000
# 75%        43.000000       4.363521              0.0         1.000000
# max        43.000000       5.397270              0.0         1.000000
#
#        contains_equal  contains_question        is_form
# count   123042.000000      123042.000000  123042.000000
# mean         0.208035           0.208132       0.211123
# std          0.405903           0.405974       0.408107
# min          0.000000           0.000000       0.000000
# 25%          0.000000           0.000000       0.000000
# 50%          0.000000           0.000000       0.000000
# 75%          0.000000           0.000000       0.000000
# max          1.000000           1.000000       1.000000

# %% [markdown]
# *— Matrice de corrélation :*

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(X.corr(), cmap="coolwarm", annot=False)
plt.title("Matrice de corrélation des features")
plt.show()
