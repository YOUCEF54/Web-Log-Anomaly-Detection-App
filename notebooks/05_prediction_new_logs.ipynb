# %% [markdown]
# # 📌 05 – Predicting Anomalies on New Logs
#
# “This notebook loads the trained models and performs anomaly prediction on new HTTP logs, demonstrating real-world detection capability.”

# %% [markdown]
# *– Imports :*

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

import pandas as pd
import joblib
import tempfile

# %% [markdown]
# *— Import official Apache parser :*

# %%
from parse_logs import parse_apache_log_lines
from predict import predict_file

print("✔ Apache parser imported")
print("✔ predict_file imported")
# Out:
# ✔ Apache parser imported
# ✔ predict_file imported

# %% [markdown]
# ⭐ Test — Example: Predict anomalies from sample_access.log :

# %% [markdown]
# *— Load log file :*

# %%
log_path = "../data/sample_access.log"

with open(log_path, "r", encoding="utf-8", errors="ignore") as f:
    lines = f.readlines()

print("✔ Loaded", len(lines), "log lines")
# Out:
# ✔ Loaded 94 log lines

# %% [markdown]
# *–— Parse into a DataFrame compatible with features.py :*

# %%
df_logs = parse_apache_log_lines(lines)
print("Parsed rows:", len(df_logs))
df_logs.head()
# Out:
# Parsed rows: 94
#   method                                           url  protocol status  \
# 0    GET                                    /index.jsp  HTTP/1.1    200
# 1    GET  /tienda1/publico/anadir.jsp?id=3&nombre=Vino  HTTP/1.1    200
# 2    GET                              /images/logo.png  HTTP/1.1    200
# 3    GET                                /products/list  HTTP/1.1    200
# 4    GET                                      /contact  HTTP/1.1    200
#
#   content_length     user_agent cookie content_type body
# 0            532    Mozilla/5.0
# 1            645    Mozilla/5.0
# 2           1203   Chrome/120.0
# 3            900    Safari/17.0
# 4            800  Firefox/109.0

# %% [markdown]
# *— Ensure required columns for build_features() :*

# %%
required_cols = [
    "url", "method", "body", "user_agent",
    "cookie", "content_type", "content_length"
]

for col in required_cols:
    if col not in df_logs.columns:
        df_logs[col] = ""

# Ensure numeric
df_logs["content_length"] = df_logs["content_length"].astype(str)

df_logs = df_logs[required_cols]

df_logs.head()
# Out:
#                                             url method body     user_agent  \
# 0                                    /index.jsp    GET         Mozilla/5.0
# 1  /tienda1/publico/anadir.jsp?id=3&nombre=Vino    GET         Mozilla/5.0
# 2                              /images/logo.png    GET        Chrome/120.0
# 3                                /products/list    GET         Safari/17.0
# 4                                      /contact    GET       Firefox/109.0
#
#   cookie content_type content_length
# 0                                532
# 1                                645
# 2                               1203
# 3                                900
# 4                                800

# %% [markdown]
# *— Save temp CSV then run predict_file() :*

# %%
temp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
df_logs.to_csv(temp_file.name, index=False, encoding="utf-8")

print("✔ Temporary CSV created at:")
print(temp_file.name)

results = predict_file(temp_file.name)

print("\n===  Predictions Preview ===")
results.head()
# Out:
# ✔ Temporary CSV created at:
# C:\Users\ok\AppData\Local\Temp\tmp5jjfslbv.csv
#
# ===  Predictions Preview ===
#                                             url method  body     user_agent  \
# 0                                    /index.jsp    GET   NaN    Mozilla/5.0
# 1  /tienda1/publico/anadir.jsp?id=3&nombre=Vino    GET   NaN    Mozilla/5.0
# 2                              /images/logo.png    GET   NaN   Chrome/120.0
# 3                                /products/list    GET   NaN    Safari/17.0
# 4                                      /contact    GET   NaN  Firefox/109.0
#
#    cookie  content_type  content_length  RF_Prediction  ISO_Prediction  \
# 0     NaN           NaN             532              1               0
# 1     NaN           NaN             645              1               0
# 2     NaN           NaN            1203              1               0
# 3     NaN           NaN             900              1               0
# ...
